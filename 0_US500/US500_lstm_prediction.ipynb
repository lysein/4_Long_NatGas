# %% [markdown]
# ### Import the necessary libraries

# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
import yfinance as yf
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Set random value

# %%
tf.random.set_seed(0)

# %%
ticker = "^GSPC"

# %%
# download the data
df = yf.download(tickers=ticker, period='2y')
y = df['Close'].fillna(method='ffill')
y = y.values.reshape(-1, 1)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(y)
y = scaler.transform(y)

# %%
# generate the input and output sequences
n_lookback = 120  # length of input sequences (lookback period)
n_forecast = 60  # length of output sequences (forecast period)

# %%
X = []
Y = []

for i in range(n_lookback, len(y) - n_forecast + 1):
    X.append(y[i - n_lookback: i])
    Y.append(y[i: i + n_forecast])

# %%
X = np.array(X)

# %%
Y = np.array(Y)

# %%
# fit the model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(n_lookback, 1)))
model.add(LSTM(units=50))
model.add(Dense(n_forecast))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X, Y, epochs=100, batch_size=32, verbose=2)
# Out:
# Epoch 1/100
# 11/11 - 4s - loss: 0.2323 - 4s/epoch - 355ms/step
# Epoch 2/100
# 11/11 - 1s - loss: 0.1044 - 516ms/epoch - 47ms/step
# Epoch 3/100
# 11/11 - 1s - loss: 0.0528 - 507ms/epoch - 46ms/step
# Epoch 4/100
# 11/11 - 1s - loss: 0.0383 - 518ms/epoch - 47ms/step
# Epoch 5/100
# 11/11 - 1s - loss: 0.0365 - 507ms/epoch - 46ms/step
# Epoch 6/100
# 11/11 - 1s - loss: 0.0365 - 504ms/epoch - 46ms/step
# Epoch 7/100
# 11/11 - 1s - loss: 0.0374 - 504ms/epoch - 46ms/step
# Epoch 8/100
# 11/11 - 1s - loss: 0.0352 - 506ms/epoch - 46ms/step
# Epoch 9/100
# 11/11 - 1s - loss: 0.0331 - 505ms/epoch - 46ms/step
# Epoch 10/100
# 11/11 - 1s - loss: 0.0327 - 514ms/epoch - 47ms/step
# Epoch 11/100
# 11/11 - 1s - loss: 0.0329 - 508ms/epoch - 46ms/step
# Epoch 12/100
# 11/11 - 1s - loss: 0.0326 - 517ms/epoch - 47ms/step
# Epoch 13/100
# 11/11 - 1s - loss: 0.0319 - 534ms/epoch - 49ms/step
# Epoch 14/100
# 11/11 - 1s - loss: 0.0316 - 537ms/epoch - 49ms/step
# Epoch 15/100
# 11/11 - 1s - loss: 0.0317 - 578ms/epoch - 53ms/step
# Epoch 16/100
# 11/11 - 1s - loss: 0.0326 - 533ms/epoch - 48ms/step
# Epoch 17/100
# 11/11 - 0s - loss: 0.0333 - 499ms/epoch - 45ms/step
# Epoch 18/100
# 11/11 - 0s - loss: 0.0310 - 499ms/epoch - 45ms/step
# Epoch 19/100
# 11/11 - 0s - loss: 0.0302 - 498ms/epoch - 45ms/step
# Epoch 20/100
# 11/11 - 0s - loss: 0.0309 - 499ms/epoch - 45ms/step
# Epoch 21/100
# 11/11 - 1s - loss: 0.0276 - 501ms/epoch - 46ms/step
# Epoch 22/100
# 11/11 - 1s - loss: 0.0225 - 520ms/epoch - 47ms/step
# Epoch 23/100
# 11/11 - 1s - loss: 0.0221 - 502ms/epoch - 46ms/step
# Epoch 24/100
# 11/11 - 0s - loss: 0.0184 - 493ms/epoch - 45ms/step
# Epoch 25/100
# 11/11 - 0s - loss: 0.0170 - 496ms/epoch - 45ms/step
# Epoch 26/100
# 11/11 - 1s - loss: 0.0160 - 503ms/epoch - 46ms/step
# Epoch 27/100
# 11/11 - 1s - loss: 0.0161 - 511ms/epoch - 46ms/step
# Epoch 28/100
# 11/11 - 1s - loss: 0.0166 - 503ms/epoch - 46ms/step
# Epoch 29/100
# 11/11 - 1s - loss: 0.0159 - 520ms/epoch - 47ms/step
# Epoch 30/100
# 11/11 - 1s - loss: 0.0153 - 502ms/epoch - 46ms/step
# Epoch 31/100
# 11/11 - 0s - loss: 0.0145 - 500ms/epoch - 45ms/step
# Epoch 32/100
# 11/11 - 0s - loss: 0.0141 - 495ms/epoch - 45ms/step
# Epoch 33/100
# 11/11 - 0s - loss: 0.0139 - 497ms/epoch - 45ms/step
# Epoch 34/100
# 11/11 - 0s - loss: 0.0136 - 493ms/epoch - 45ms/step
# Epoch 35/100
# 11/11 - 0s - loss: 0.0133 - 497ms/epoch - 45ms/step
# Epoch 36/100
# 11/11 - 0s - loss: 0.0131 - 493ms/epoch - 45ms/step
# Epoch 37/100
# 11/11 - 1s - loss: 0.0128 - 546ms/epoch - 50ms/step
# Epoch 38/100
# 11/11 - 1s - loss: 0.0128 - 598ms/epoch - 54ms/step
# Epoch 39/100
# 11/11 - 1s - loss: 0.0128 - 600ms/epoch - 55ms/step
# Epoch 40/100
# 11/11 - 1s - loss: 0.0122 - 598ms/epoch - 54ms/step
# Epoch 41/100
# 11/11 - 1s - loss: 0.0123 - 606ms/epoch - 55ms/step
# Epoch 42/100
# 11/11 - 1s - loss: 0.0127 - 596ms/epoch - 54ms/step
# Epoch 43/100
# 11/11 - 1s - loss: 0.0119 - 596ms/epoch - 54ms/step
# Epoch 44/100
# 11/11 - 1s - loss: 0.0112 - 598ms/epoch - 54ms/step
# Epoch 45/100
# 11/11 - 1s - loss: 0.0111 - 596ms/epoch - 54ms/step
# Epoch 46/100
# 11/11 - 1s - loss: 0.0114 - 607ms/epoch - 55ms/step
# Epoch 47/100
# 11/11 - 1s - loss: 0.0108 - 601ms/epoch - 55ms/step
# Epoch 48/100
# 11/11 - 1s - loss: 0.0107 - 595ms/epoch - 54ms/step
# Epoch 49/100
# 11/11 - 1s - loss: 0.0104 - 632ms/epoch - 57ms/step
# Epoch 50/100
# 11/11 - 1s - loss: 0.0104 - 617ms/epoch - 56ms/step
# Epoch 51/100
# 11/11 - 1s - loss: 0.0102 - 608ms/epoch - 55ms/step
# Epoch 52/100
# 11/11 - 1s - loss: 0.0101 - 595ms/epoch - 54ms/step
# Epoch 53/100
# 11/11 - 1s - loss: 0.0100 - 593ms/epoch - 54ms/step
# Epoch 54/100
# 11/11 - 1s - loss: 0.0100 - 598ms/epoch - 54ms/step
# Epoch 55/100
# 11/11 - 1s - loss: 0.0100 - 589ms/epoch - 54ms/step
# Epoch 56/100
# 11/11 - 1s - loss: 0.0098 - 595ms/epoch - 54ms/step
# Epoch 57/100
# 11/11 - 1s - loss: 0.0097 - 600ms/epoch - 55ms/step
# Epoch 58/100
# 11/11 - 1s - loss: 0.0098 - 600ms/epoch - 55ms/step
# Epoch 59/100
# 11/11 - 1s - loss: 0.0096 - 588ms/epoch - 53ms/step
# Epoch 60/100
# 11/11 - 1s - loss: 0.0097 - 587ms/epoch - 53ms/step
# Epoch 61/100
# 11/11 - 1s - loss: 0.0096 - 589ms/epoch - 54ms/step
# Epoch 62/100
# 11/11 - 1s - loss: 0.0096 - 599ms/epoch - 54ms/step
# Epoch 63/100
# 11/11 - 1s - loss: 0.0094 - 590ms/epoch - 54ms/step
# Epoch 64/100
# 11/11 - 1s - loss: 0.0092 - 589ms/epoch - 54ms/step
# Epoch 65/100
# 11/11 - 1s - loss: 0.0093 - 592ms/epoch - 54ms/step
# Epoch 66/100
# 11/11 - 1s - loss: 0.0090 - 593ms/epoch - 54ms/step
# Epoch 67/100
# 11/11 - 1s - loss: 0.0092 - 588ms/epoch - 53ms/step
# Epoch 68/100
# 11/11 - 1s - loss: 0.0089 - 591ms/epoch - 54ms/step
# Epoch 69/100
# 11/11 - 1s - loss: 0.0089 - 600ms/epoch - 55ms/step
# Epoch 70/100
# 11/11 - 1s - loss: 0.0087 - 596ms/epoch - 54ms/step
# Epoch 71/100
# 11/11 - 1s - loss: 0.0087 - 594ms/epoch - 54ms/step
# Epoch 72/100
# 11/11 - 1s - loss: 0.0089 - 619ms/epoch - 56ms/step
# Epoch 73/100
# 11/11 - 1s - loss: 0.0085 - 589ms/epoch - 54ms/step
# Epoch 74/100
# 11/11 - 1s - loss: 0.0082 - 598ms/epoch - 54ms/step
# Epoch 75/100
# 11/11 - 1s - loss: 0.0085 - 598ms/epoch - 54ms/step
# Epoch 76/100
# 11/11 - 1s - loss: 0.0085 - 589ms/epoch - 54ms/step
# Epoch 77/100
# 11/11 - 1s - loss: 0.0082 - 591ms/epoch - 54ms/step
# Epoch 78/100
# 11/11 - 1s - loss: 0.0080 - 600ms/epoch - 55ms/step
# Epoch 79/100
# 11/11 - 1s - loss: 0.0081 - 595ms/epoch - 54ms/step
# Epoch 80/100
# 11/11 - 1s - loss: 0.0079 - 592ms/epoch - 54ms/step
# Epoch 81/100
# 11/11 - 1s - loss: 0.0076 - 605ms/epoch - 55ms/step
# Epoch 82/100
# 11/11 - 1s - loss: 0.0080 - 593ms/epoch - 54ms/step
# Epoch 83/100
# 11/11 - 1s - loss: 0.0084 - 596ms/epoch - 54ms/step
# Epoch 84/100
# 11/11 - 1s - loss: 0.0085 - 590ms/epoch - 54ms/step
# Epoch 85/100
# 11/11 - 1s - loss: 0.0078 - 600ms/epoch - 55ms/step
# Epoch 86/100
# 11/11 - 1s - loss: 0.0073 - 598ms/epoch - 54ms/step
# Epoch 87/100
# 11/11 - 1s - loss: 0.0068 - 591ms/epoch - 54ms/step
# Epoch 88/100
# 11/11 - 1s - loss: 0.0066 - 608ms/epoch - 55ms/step
# Epoch 89/100
# 11/11 - 1s - loss: 0.0070 - 678ms/epoch - 62ms/step
# Epoch 90/100
# 11/11 - 1s - loss: 0.0075 - 599ms/epoch - 54ms/step
# Epoch 91/100
# 11/11 - 1s - loss: 0.0075 - 593ms/epoch - 54ms/step
# Epoch 92/100
# 11/11 - 1s - loss: 0.0072 - 591ms/epoch - 54ms/step
# Epoch 93/100
# 11/11 - 1s - loss: 0.0066 - 585ms/epoch - 53ms/step
# Epoch 94/100
# 11/11 - 1s - loss: 0.0065 - 592ms/epoch - 54ms/step
# Epoch 95/100
# 11/11 - 1s - loss: 0.0066 - 586ms/epoch - 53ms/step
# Epoch 96/100
# 11/11 - 1s - loss: 0.0059 - 593ms/epoch - 54ms/step
# Epoch 97/100
# 11/11 - 1s - loss: 0.0059 - 591ms/epoch - 54ms/step
# Epoch 98/100
# 11/11 - 1s - loss: 0.0057 - 684ms/epoch - 62ms/step
# Epoch 99/100
# 11/11 - 1s - loss: 0.0059 - 607ms/epoch - 55ms/step
# Epoch 100/100
# 11/11 - 1s - loss: 0.0057 - 601ms/epoch - 55ms/step

# %%
# generate the forecasts
X_ = y[- n_lookback:]  # last available input sequence
X_ = X_.reshape(1, n_lookback, 1)

Y_ = model.predict(X_).reshape(-1, 1)
Y_ = scaler.inverse_transform(Y_)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000249FB2D8E50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 651ms/step

# %%
# organize the results in a data frame
df_past = df[['Close']].reset_index()
df_past.rename(columns={'index': 'Date', 'Close': 'Actual'}, inplace=True)
df_past['Date'] = pd.to_datetime(df_past['Date'])
df_past['Forecast'] = np.nan
df_past['Forecast'].iloc[-1] = df_past['Actual'].iloc[-1]

df_future = pd.DataFrame(columns=['Date', 'Actual', 'Forecast'])
df_future['Date'] = pd.date_range(start=df_past['Date'].iloc[-1] + pd.Timedelta(days=1), periods=n_forecast)
df_future['Forecast'] = Y_.flatten()
df_future['Actual'] = np.nan

# %%
import matplotlib.pyplot as plt

# %%
results = pd.concat([df_past, df_future]).set_index("Date")
# plot the results
plt.style.use('dark_background')
results.plot(title=ticker)
# Out:
# <Axes: title={'center': '^GSPC'}, xlabel='Date'>

# %%
# Using plotly.express
import plotly.express as px
import plotly.io as pio
pio.templates
templates = ['ggplot2', 'seaborn', 'simple_white', 'plotly',
         'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
         'ygridoff', 'gridon', 'none']

# %%
plot_df = results.reset_index()
fig = px.line(plot_df, x="Date", y=results.columns,
          title=f"{ticker} {n_forecast} Forecast", #, {min(df["timestamp"].dt.date)}, {max(df["timestamp"].dt.date)}',
          template=templates[5])
#time.sleep(2)
fig.show()
