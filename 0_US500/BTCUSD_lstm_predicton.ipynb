# %% [markdown]
# ### Import the necessary libraries

# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
import yfinance as yf
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Set random value

# %%
tf.random.set_seed(0)

# %%
ticker = "BTC-USD"

# %%
# download the data
df = yf.download(tickers=ticker, period='5y')
y = df['Close'].fillna(method='ffill')
y = y.values.reshape(-1, 1)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(y)
y = scaler.transform(y)

# %%
# generate the input and output sequences
n_lookback = 180  # length of input sequences (lookback period)
n_forecast = 90  # length of output sequences (forecast period)

# %%
X = []
Y = []

for i in range(n_lookback, len(y) - n_forecast + 1):
    X.append(y[i - n_lookback: i])
    Y.append(y[i: i + n_forecast])

# %%
X = np.array(X)

# %%
Y = np.array(Y)

# %%
# fit the model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(n_lookback, 1)))
model.add(LSTM(units=50))
model.add(Dense(n_forecast))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X, Y, epochs=100, batch_size=32, verbose=2)
# Out:
# Epoch 1/100
# 49/49 - 7s - loss: 0.0583 - 7s/epoch - 145ms/step
# Epoch 2/100
# 49/49 - 4s - loss: 0.0152 - 4s/epoch - 76ms/step
# Epoch 3/100
# 49/49 - 5s - loss: 0.0143 - 5s/epoch - 96ms/step
# Epoch 4/100
# 49/49 - 5s - loss: 0.0142 - 5s/epoch - 102ms/step
# Epoch 5/100
# 49/49 - 5s - loss: 0.0139 - 5s/epoch - 102ms/step
# Epoch 6/100
# 49/49 - 5s - loss: 0.0136 - 5s/epoch - 102ms/step
# Epoch 7/100
# 49/49 - 5s - loss: 0.0130 - 5s/epoch - 102ms/step
# Epoch 8/100
# 49/49 - 5s - loss: 0.0115 - 5s/epoch - 103ms/step
# Epoch 9/100
# 49/49 - 5s - loss: 0.0114 - 5s/epoch - 105ms/step
# Epoch 10/100
# 49/49 - 5s - loss: 0.0105 - 5s/epoch - 104ms/step
# Epoch 11/100
# 49/49 - 5s - loss: 0.0100 - 5s/epoch - 105ms/step
# Epoch 12/100
# 49/49 - 5s - loss: 0.0102 - 5s/epoch - 107ms/step
# Epoch 13/100
# 49/49 - 5s - loss: 0.0097 - 5s/epoch - 107ms/step
# Epoch 14/100
# 49/49 - 5s - loss: 0.0095 - 5s/epoch - 108ms/step
# Epoch 15/100
# 49/49 - 5s - loss: 0.0095 - 5s/epoch - 110ms/step
# Epoch 16/100
# 49/49 - 5s - loss: 0.0091 - 5s/epoch - 110ms/step
# Epoch 17/100
# 49/49 - 5s - loss: 0.0086 - 5s/epoch - 111ms/step
# Epoch 18/100
# 49/49 - 6s - loss: 0.0094 - 6s/epoch - 119ms/step
# Epoch 19/100
# 49/49 - 5s - loss: 0.0089 - 5s/epoch - 108ms/step
# Epoch 20/100
# 49/49 - 5s - loss: 0.0086 - 5s/epoch - 107ms/step
# Epoch 21/100
# 49/49 - 6s - loss: 0.0086 - 6s/epoch - 117ms/step
# Epoch 22/100
# 49/49 - 6s - loss: 0.0088 - 6s/epoch - 131ms/step
# Epoch 23/100
# 49/49 - 7s - loss: 0.0085 - 7s/epoch - 141ms/step
# Epoch 24/100
# 49/49 - 6s - loss: 0.0084 - 6s/epoch - 120ms/step
# Epoch 25/100
# 49/49 - 6s - loss: 0.0082 - 6s/epoch - 122ms/step
# Epoch 26/100
# 49/49 - 6s - loss: 0.0085 - 6s/epoch - 115ms/step
# Epoch 27/100
# 49/49 - 6s - loss: 0.0082 - 6s/epoch - 123ms/step
# Epoch 28/100
# 49/49 - 5s - loss: 0.0076 - 5s/epoch - 104ms/step
# Epoch 29/100
# 49/49 - 5s - loss: 0.0078 - 5s/epoch - 104ms/step
# Epoch 30/100
# 49/49 - 5s - loss: 0.0073 - 5s/epoch - 104ms/step
# Epoch 31/100
# 49/49 - 5s - loss: 0.0087 - 5s/epoch - 103ms/step
# Epoch 32/100
# 49/49 - 5s - loss: 0.0088 - 5s/epoch - 104ms/step
# Epoch 33/100
# 49/49 - 5s - loss: 0.0069 - 5s/epoch - 103ms/step
# Epoch 34/100
# 49/49 - 5s - loss: 0.0069 - 5s/epoch - 104ms/step
# Epoch 35/100
# 49/49 - 5s - loss: 0.0060 - 5s/epoch - 103ms/step
# Epoch 36/100
# 49/49 - 5s - loss: 0.0053 - 5s/epoch - 103ms/step
# Epoch 37/100
# 49/49 - 5s - loss: 0.0103 - 5s/epoch - 104ms/step
# Epoch 38/100
# 49/49 - 5s - loss: 0.0082 - 5s/epoch - 103ms/step
# Epoch 39/100
# 49/49 - 5s - loss: 0.0081 - 5s/epoch - 103ms/step
# Epoch 40/100
# 49/49 - 5s - loss: 0.0080 - 5s/epoch - 106ms/step
# Epoch 41/100
# 49/49 - 5s - loss: 0.0078 - 5s/epoch - 103ms/step
# Epoch 42/100
# 49/49 - 5s - loss: 0.0076 - 5s/epoch - 103ms/step
# Epoch 43/100
# 49/49 - 5s - loss: 0.0074 - 5s/epoch - 105ms/step
# Epoch 44/100
# 49/49 - 5s - loss: 0.0074 - 5s/epoch - 103ms/step
# Epoch 45/100
# 49/49 - 7s - loss: 0.0079 - 7s/epoch - 139ms/step
# Epoch 46/100
# 49/49 - 5s - loss: 0.0062 - 5s/epoch - 104ms/step
# Epoch 47/100
# 49/49 - 5s - loss: 0.0105 - 5s/epoch - 104ms/step
# Epoch 48/100
# 49/49 - 5s - loss: 0.0071 - 5s/epoch - 103ms/step
# Epoch 49/100
# 49/49 - 5s - loss: 0.0057 - 5s/epoch - 104ms/step
# Epoch 50/100
# 49/49 - 5s - loss: 0.0047 - 5s/epoch - 103ms/step
# Epoch 51/100
# 49/49 - 5s - loss: 0.0084 - 5s/epoch - 103ms/step
# Epoch 52/100
# 49/49 - 5s - loss: 0.0070 - 5s/epoch - 103ms/step
# Epoch 53/100
# 49/49 - 5s - loss: 0.0045 - 5s/epoch - 105ms/step
# Epoch 54/100
# 49/49 - 5s - loss: 0.0122 - 5s/epoch - 105ms/step
# Epoch 55/100
# 49/49 - 5s - loss: 0.0145 - 5s/epoch - 103ms/step
# Epoch 56/100
# 49/49 - 5s - loss: 0.0120 - 5s/epoch - 104ms/step
# Epoch 57/100
# 49/49 - 5s - loss: 0.0098 - 5s/epoch - 104ms/step
# Epoch 58/100
# 49/49 - 5s - loss: 0.0109 - 5s/epoch - 103ms/step
# Epoch 59/100
# 49/49 - 5s - loss: 0.0113 - 5s/epoch - 103ms/step
# Epoch 60/100
# 49/49 - 5s - loss: 0.0107 - 5s/epoch - 103ms/step
# Epoch 61/100
# 49/49 - 5s - loss: 0.0093 - 5s/epoch - 104ms/step
# Epoch 62/100
# 49/49 - 5s - loss: 0.0087 - 5s/epoch - 104ms/step
# Epoch 63/100
# 49/49 - 5s - loss: 0.0083 - 5s/epoch - 104ms/step
# Epoch 64/100
# 49/49 - 5s - loss: 0.0079 - 5s/epoch - 104ms/step
# Epoch 65/100
# 49/49 - 5s - loss: 0.0090 - 5s/epoch - 105ms/step
# Epoch 66/100
# 49/49 - 5s - loss: 0.0090 - 5s/epoch - 104ms/step
# Epoch 67/100
# 49/49 - 5s - loss: 0.0095 - 5s/epoch - 103ms/step
# Epoch 68/100
# 49/49 - 5s - loss: 0.0081 - 5s/epoch - 104ms/step
# Epoch 69/100
# 49/49 - 5s - loss: 0.0070 - 5s/epoch - 103ms/step
# Epoch 70/100
# 49/49 - 5s - loss: 0.0077 - 5s/epoch - 104ms/step
# Epoch 71/100
# 49/49 - 5s - loss: 0.0057 - 5s/epoch - 104ms/step
# Epoch 72/100
# 49/49 - 5s - loss: 0.0105 - 5s/epoch - 103ms/step
# Epoch 73/100
# 49/49 - 5s - loss: 0.0083 - 5s/epoch - 103ms/step
# Epoch 74/100
# 49/49 - 5s - loss: 0.0081 - 5s/epoch - 107ms/step
# Epoch 75/100
# 49/49 - 5s - loss: 0.0077 - 5s/epoch - 103ms/step
# Epoch 76/100
# 49/49 - 5s - loss: 0.0079 - 5s/epoch - 103ms/step
# Epoch 77/100
# 49/49 - 5s - loss: 0.0072 - 5s/epoch - 106ms/step
# Epoch 78/100
# 49/49 - 5s - loss: 0.0071 - 5s/epoch - 108ms/step
# Epoch 79/100
# 49/49 - 5s - loss: 0.0073 - 5s/epoch - 108ms/step
# Epoch 80/100
# 49/49 - 5s - loss: 0.0080 - 5s/epoch - 103ms/step
# Epoch 81/100
# 49/49 - 5s - loss: 0.0071 - 5s/epoch - 103ms/step
# Epoch 82/100
# 49/49 - 5s - loss: 0.0081 - 5s/epoch - 112ms/step
# Epoch 83/100
# 49/49 - 5s - loss: 0.0075 - 5s/epoch - 106ms/step
# Epoch 84/100
# 49/49 - 5s - loss: 0.0073 - 5s/epoch - 104ms/step
# Epoch 85/100
# 49/49 - 5s - loss: 0.0082 - 5s/epoch - 103ms/step
# Epoch 86/100
# 49/49 - 5s - loss: 0.0075 - 5s/epoch - 103ms/step
# Epoch 87/100
# 49/49 - 5s - loss: 0.0072 - 5s/epoch - 103ms/step
# Epoch 88/100
# 49/49 - 5s - loss: 0.0062 - 5s/epoch - 103ms/step
# Epoch 89/100
# 49/49 - 5s - loss: 0.0063 - 5s/epoch - 103ms/step
# Epoch 90/100
# 49/49 - 5s - loss: 0.0045 - 5s/epoch - 103ms/step
# Epoch 91/100
# 49/49 - 5s - loss: 0.0042 - 5s/epoch - 104ms/step
# Epoch 92/100
# 49/49 - 5s - loss: 0.0037 - 5s/epoch - 103ms/step
# Epoch 93/100
# 49/49 - 5s - loss: 0.0036 - 5s/epoch - 103ms/step
# Epoch 94/100
# 49/49 - 5s - loss: 0.0134 - 5s/epoch - 104ms/step
# Epoch 95/100
# 49/49 - 5s - loss: 0.0128 - 5s/epoch - 103ms/step
# Epoch 96/100
# 49/49 - 5s - loss: 0.0119 - 5s/epoch - 104ms/step
# Epoch 97/100
# 49/49 - 5s - loss: 0.0118 - 5s/epoch - 103ms/step
# Epoch 98/100
# 49/49 - 5s - loss: 0.0132 - 5s/epoch - 103ms/step
# Epoch 99/100
# 49/49 - 5s - loss: 0.0107 - 5s/epoch - 103ms/step
# Epoch 100/100
# 49/49 - 5s - loss: 0.0092 - 5s/epoch - 103ms/step

# %%
# generate the forecasts
X_ = y[- n_lookback:]  # last available input sequence
X_ = X_.reshape(1, n_lookback, 1)

Y_ = model.predict(X_).reshape(-1, 1)
Y_ = scaler.inverse_transform(Y_)
# Out:
# 1/1 [==============================] - 1s 734ms/step

# %%
# organize the results in a data frame
df_past = df[['Close']].reset_index()
df_past.rename(columns={'index': 'Date', 'Close': 'Actual'}, inplace=True)
df_past['Date'] = pd.to_datetime(df_past['Date'])
df_past['Forecast'] = np.nan
df_past['Forecast'].iloc[-1] = df_past['Actual'].iloc[-1]

df_future = pd.DataFrame(columns=['Date', 'Actual', 'Forecast'])
df_future['Date'] = pd.date_range(start=df_past['Date'].iloc[-1] + pd.Timedelta(days=1), periods=n_forecast)
df_future['Forecast'] = Y_.flatten()
df_future['Actual'] = np.nan

# %%
import matplotlib.pyplot as plt

# %%
results = pd.concat([df_past, df_future]).set_index("Date")
# plot the results
plt.style.use('dark_background')
results.plot(title=ticker)
# Out:
# <Axes: title={'center': 'BTC-USD'}, xlabel='Date'>

# %%
# Using plotly.express
import plotly.express as px
import plotly.io as pio
pio.templates
templates = ['ggplot2', 'seaborn', 'simple_white', 'plotly',
         'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
         'ygridoff', 'gridon', 'none']

# %%
plot_df = results.reset_index()
fig = px.line(plot_df, x="Date", y=results.columns,
          title=f"{ticker} {n_forecast} Forecast", #, {min(df["timestamp"].dt.date)}, {max(df["timestamp"].dt.date)}',
          template=templates[5])
#time.sleep(2)
fig.show()
