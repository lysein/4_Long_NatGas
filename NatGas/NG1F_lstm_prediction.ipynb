# %% [markdown]
# ### Import the necessary libraries

# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
import yfinance as yf
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %% [markdown]
# Set random value

# %%
ticker = "NG=F"

# %%
tf.random.set_seed(0)

# %%
# download the data
df = yf.download(tickers=ticker, period='2y')
y = df['Close'].fillna(method='ffill')
y = y.values.reshape(-1, 1)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(y)
y = scaler.transform(y)

# %%
# generate the input and output sequences
n_lookback = 120  # length of input sequences (lookback period)
n_forecast = 60  # length of output sequences (forecast period)

# %%
X = []
Y = []

for i in range(n_lookback, len(y) - n_forecast + 1):
    X.append(y[i - n_lookback: i])
    Y.append(y[i: i + n_forecast])

# %%
X = np.array(X)

# %%
Y = np.array(Y)

# %%
# fit the model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(n_lookback, 1)))
model.add(LSTM(units=50))
model.add(Dense(n_forecast))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X, Y, epochs=100, batch_size=32, verbose=2)
# Out:
# Epoch 1/100
# 11/11 - 4s - loss: 0.2735 - 4s/epoch - 348ms/step
# Epoch 2/100
# 11/11 - 1s - loss: 0.1372 - 525ms/epoch - 48ms/step
# Epoch 3/100
# 11/11 - 1s - loss: 0.0745 - 516ms/epoch - 47ms/step
# Epoch 4/100
# 11/11 - 1s - loss: 0.0582 - 507ms/epoch - 46ms/step
# Epoch 5/100
# 11/11 - 1s - loss: 0.0552 - 518ms/epoch - 47ms/step
# Epoch 6/100
# 11/11 - 1s - loss: 0.0513 - 587ms/epoch - 53ms/step
# Epoch 7/100
# 11/11 - 1s - loss: 0.0511 - 543ms/epoch - 49ms/step
# Epoch 8/100
# 11/11 - 1s - loss: 0.0504 - 560ms/epoch - 51ms/step
# Epoch 9/100
# 11/11 - 1s - loss: 0.0523 - 508ms/epoch - 46ms/step
# Epoch 10/100
# 11/11 - 1s - loss: 0.0491 - 530ms/epoch - 48ms/step
# Epoch 11/100
# 11/11 - 1s - loss: 0.0486 - 510ms/epoch - 46ms/step
# Epoch 12/100
# 11/11 - 1s - loss: 0.0485 - 513ms/epoch - 47ms/step
# Epoch 13/100
# 11/11 - 1s - loss: 0.0476 - 513ms/epoch - 47ms/step
# Epoch 14/100
# 11/11 - 1s - loss: 0.0484 - 516ms/epoch - 47ms/step
# Epoch 15/100
# 11/11 - 1s - loss: 0.0469 - 504ms/epoch - 46ms/step
# Epoch 16/100
# 11/11 - 1s - loss: 0.0466 - 569ms/epoch - 52ms/step
# Epoch 17/100
# 11/11 - 1s - loss: 0.0465 - 531ms/epoch - 48ms/step
# Epoch 18/100
# 11/11 - 1s - loss: 0.0473 - 532ms/epoch - 48ms/step
# Epoch 19/100
# 11/11 - 1s - loss: 0.0456 - 505ms/epoch - 46ms/step
# Epoch 20/100
# 11/11 - 1s - loss: 0.0453 - 514ms/epoch - 47ms/step
# Epoch 21/100
# 11/11 - 1s - loss: 0.0452 - 501ms/epoch - 46ms/step
# Epoch 22/100
# 11/11 - 1s - loss: 0.0466 - 503ms/epoch - 46ms/step
# Epoch 23/100
# 11/11 - 1s - loss: 0.0452 - 622ms/epoch - 57ms/step
# Epoch 24/100
# 11/11 - 1s - loss: 0.0441 - 680ms/epoch - 62ms/step
# Epoch 25/100
# 11/11 - 1s - loss: 0.0441 - 689ms/epoch - 63ms/step
# Epoch 26/100
# 11/11 - 1s - loss: 0.0431 - 642ms/epoch - 58ms/step
# Epoch 27/100
# 11/11 - 1s - loss: 0.0417 - 617ms/epoch - 56ms/step
# Epoch 28/100
# 11/11 - 1s - loss: 0.0392 - 621ms/epoch - 56ms/step
# Epoch 29/100
# 11/11 - 1s - loss: 0.0393 - 615ms/epoch - 56ms/step
# Epoch 30/100
# 11/11 - 1s - loss: 0.0363 - 622ms/epoch - 57ms/step
# Epoch 31/100
# 11/11 - 1s - loss: 0.0266 - 631ms/epoch - 57ms/step
# Epoch 32/100
# 11/11 - 1s - loss: 0.0242 - 613ms/epoch - 56ms/step
# Epoch 33/100
# 11/11 - 1s - loss: 0.0211 - 634ms/epoch - 58ms/step
# Epoch 34/100
# 11/11 - 1s - loss: 0.0313 - 615ms/epoch - 56ms/step
# Epoch 35/100
# 11/11 - 1s - loss: 0.0251 - 644ms/epoch - 59ms/step
# Epoch 36/100
# 11/11 - 1s - loss: 0.0222 - 619ms/epoch - 56ms/step
# Epoch 37/100
# 11/11 - 1s - loss: 0.0188 - 667ms/epoch - 61ms/step
# Epoch 38/100
# 11/11 - 1s - loss: 0.0163 - 624ms/epoch - 57ms/step
# Epoch 39/100
# 11/11 - 1s - loss: 0.0152 - 622ms/epoch - 57ms/step
# Epoch 40/100
# 11/11 - 1s - loss: 0.0143 - 684ms/epoch - 62ms/step
# Epoch 41/100
# 11/11 - 1s - loss: 0.0139 - 615ms/epoch - 56ms/step
# Epoch 42/100
# 11/11 - 1s - loss: 0.0125 - 643ms/epoch - 58ms/step
# Epoch 43/100
# 11/11 - 1s - loss: 0.0110 - 618ms/epoch - 56ms/step
# Epoch 44/100
# 11/11 - 1s - loss: 0.0107 - 705ms/epoch - 64ms/step
# Epoch 45/100
# 11/11 - 1s - loss: 0.0100 - 701ms/epoch - 64ms/step
# Epoch 46/100
# 11/11 - 1s - loss: 0.0097 - 617ms/epoch - 56ms/step
# Epoch 47/100
# 11/11 - 1s - loss: 0.0097 - 632ms/epoch - 57ms/step
# Epoch 48/100
# 11/11 - 1s - loss: 0.0096 - 613ms/epoch - 56ms/step
# Epoch 49/100
# 11/11 - 1s - loss: 0.0085 - 648ms/epoch - 59ms/step
# Epoch 50/100
# 11/11 - 1s - loss: 0.0077 - 615ms/epoch - 56ms/step
# Epoch 51/100
# 11/11 - 1s - loss: 0.0067 - 736ms/epoch - 67ms/step
# Epoch 52/100
# 11/11 - 1s - loss: 0.0062 - 652ms/epoch - 59ms/step
# Epoch 53/100
# 11/11 - 1s - loss: 0.0061 - 650ms/epoch - 59ms/step
# Epoch 54/100
# 11/11 - 1s - loss: 0.0058 - 663ms/epoch - 60ms/step
# Epoch 55/100
# 11/11 - 1s - loss: 0.0055 - 639ms/epoch - 58ms/step
# Epoch 56/100
# 11/11 - 1s - loss: 0.0055 - 686ms/epoch - 62ms/step
# Epoch 57/100
# 11/11 - 1s - loss: 0.0054 - 650ms/epoch - 59ms/step
# Epoch 58/100
# 11/11 - 1s - loss: 0.0052 - 716ms/epoch - 65ms/step
# Epoch 59/100
# 11/11 - 1s - loss: 0.0051 - 730ms/epoch - 66ms/step
# Epoch 60/100
# 11/11 - 1s - loss: 0.0050 - 655ms/epoch - 60ms/step
# Epoch 61/100
# 11/11 - 1s - loss: 0.0049 - 676ms/epoch - 61ms/step
# Epoch 62/100
# 11/11 - 1s - loss: 0.0048 - 645ms/epoch - 59ms/step
# Epoch 63/100
# 11/11 - 1s - loss: 0.0049 - 686ms/epoch - 62ms/step
# Epoch 64/100
# 11/11 - 1s - loss: 0.0049 - 659ms/epoch - 60ms/step
# Epoch 65/100
# 11/11 - 1s - loss: 0.0048 - 669ms/epoch - 61ms/step
# Epoch 66/100
# 11/11 - 1s - loss: 0.0047 - 657ms/epoch - 60ms/step
# Epoch 67/100
# 11/11 - 1s - loss: 0.0047 - 693ms/epoch - 63ms/step
# Epoch 68/100
# 11/11 - 1s - loss: 0.0045 - 681ms/epoch - 62ms/step
# Epoch 69/100
# 11/11 - 1s - loss: 0.0044 - 763ms/epoch - 69ms/step
# Epoch 70/100
# 11/11 - 1s - loss: 0.0044 - 701ms/epoch - 64ms/step
# Epoch 71/100
# 11/11 - 1s - loss: 0.0043 - 655ms/epoch - 60ms/step
# Epoch 72/100
# 11/11 - 1s - loss: 0.0044 - 693ms/epoch - 63ms/step
# Epoch 73/100
# 11/11 - 1s - loss: 0.0043 - 674ms/epoch - 61ms/step
# Epoch 74/100
# 11/11 - 1s - loss: 0.0043 - 654ms/epoch - 59ms/step
# Epoch 75/100
# 11/11 - 1s - loss: 0.0042 - 671ms/epoch - 61ms/step
# Epoch 76/100
# 11/11 - 1s - loss: 0.0042 - 658ms/epoch - 60ms/step
# Epoch 77/100
# 11/11 - 1s - loss: 0.0042 - 713ms/epoch - 65ms/step
# Epoch 78/100
# 11/11 - 1s - loss: 0.0042 - 656ms/epoch - 60ms/step
# Epoch 79/100
# 11/11 - 1s - loss: 0.0040 - 780ms/epoch - 71ms/step
# Epoch 80/100
# 11/11 - 1s - loss: 0.0041 - 709ms/epoch - 64ms/step
# Epoch 81/100
# 11/11 - 1s - loss: 0.0041 - 697ms/epoch - 63ms/step
# Epoch 82/100
# 11/11 - 1s - loss: 0.0040 - 667ms/epoch - 61ms/step
# Epoch 83/100
# 11/11 - 1s - loss: 0.0040 - 659ms/epoch - 60ms/step
# Epoch 84/100
# 11/11 - 1s - loss: 0.0043 - 712ms/epoch - 65ms/step
# Epoch 85/100
# 11/11 - 1s - loss: 0.0039 - 666ms/epoch - 61ms/step
# Epoch 86/100
# 11/11 - 1s - loss: 0.0040 - 736ms/epoch - 67ms/step
# Epoch 87/100
# 11/11 - 1s - loss: 0.0043 - 753ms/epoch - 68ms/step
# Epoch 88/100
# 11/11 - 1s - loss: 0.0041 - 675ms/epoch - 61ms/step
# Epoch 89/100
# 11/11 - 1s - loss: 0.0038 - 677ms/epoch - 62ms/step
# Epoch 90/100
# 11/11 - 1s - loss: 0.0037 - 658ms/epoch - 60ms/step
# Epoch 91/100
# 11/11 - 1s - loss: 0.0036 - 715ms/epoch - 65ms/step
# Epoch 92/100
# 11/11 - 1s - loss: 0.0037 - 672ms/epoch - 61ms/step
# Epoch 93/100
# 11/11 - 1s - loss: 0.0037 - 683ms/epoch - 62ms/step
# Epoch 94/100
# 11/11 - 1s - loss: 0.0037 - 677ms/epoch - 62ms/step
# Epoch 95/100
# 11/11 - 1s - loss: 0.0037 - 671ms/epoch - 61ms/step
# Epoch 96/100
# 11/11 - 1s - loss: 0.0037 - 675ms/epoch - 61ms/step
# Epoch 97/100
# 11/11 - 1s - loss: 0.0036 - 668ms/epoch - 61ms/step
# Epoch 98/100
# 11/11 - 1s - loss: 0.0035 - 662ms/epoch - 60ms/step
# Epoch 99/100
# 11/11 - 1s - loss: 0.0034 - 675ms/epoch - 61ms/step
# Epoch 100/100
# 11/11 - 1s - loss: 0.0035 - 653ms/epoch - 59ms/step

# %%
# generate the forecasts
X_ = y[- n_lookback:]  # last available input sequence
X_ = X_.reshape(1, n_lookback, 1)

Y_ = model.predict(X_).reshape(-1, 1)
Y_ = scaler.inverse_transform(Y_)
# Out:
# 1/1 [==============================] - 1s 749ms/step

# %%
# organize the results in a data frame
df_past = df[['Close']].reset_index()
df_past.rename(columns={'index': 'Date', 'Close': 'Actual'}, inplace=True)
df_past['Date'] = pd.to_datetime(df_past['Date'])
df_past['Forecast'] = np.nan
df_past['Forecast'].iloc[-1] = df_past['Actual'].iloc[-1]

df_future = pd.DataFrame(columns=['Date', 'Actual', 'Forecast'])
df_future['Date'] = pd.date_range(start=df_past['Date'].iloc[-1] + pd.Timedelta(days=1), periods=n_forecast)
df_future['Forecast'] = Y_.flatten()
df_future['Actual'] = np.nan

# %%
results = pd.concat([df_past, df_future]).set_index("Date")
# plot the results
plt.style.use('dark_background')
results.plot(title=ticker)
# Out:
# <Axes: title={'center': 'NG=F'}, xlabel='Date'>

# %%
# Using plotly.express
import plotly.express as px
import plotly.io as pio
pio.templates
templates = ['ggplot2', 'seaborn', 'simple_white', 'plotly',
         'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
         'ygridoff', 'gridon', 'none']

# %%
plot_df = results.reset_index()
fig = px.line(plot_df, x="Date", y=results.columns,
          title=f"Natural Gas Futures 90d Forecast", #, {min(df["timestamp"].dt.date)}, {max(df["timestamp"].dt.date)}',
          template=templates[5])
#time.sleep(2)
fig.show()
